# %%
import os, sys
sys.path.append(os.path.abspath(os.path.join('../src')))
from w_gan import *

# %matplotlib inline

# %%
# Load in binzarized MNIST data, separate into data loaders
train_iter, val_iter, test_iter = get_data()

# Init model
model = WGAN(image_size=784,
             hidden_dim=400,
             z_dim=20,
             output_dim=1)

# %%
# Init trainer
trainer = WGANTrainer(model=model,
                      train_iter=train_iter,
                      val_iter=val_iter,
                      test_iter=test_iter,
                      viz=True)

# Train
trainer.train(num_epochs=25,
              G_lr=5e-5,
              D_lr=5e-5,
              D_steps=5)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch[1/25], G Loss: -0.4863, D Loss: -0.0554
#   4%|▍         | 1/25 [00:02<01:08,  2.87s/it]
# Epoch[2/25], G Loss: -0.4833, D Loss: -0.0566
#   8%|▊         | 2/25 [00:05<01:06,  2.91s/it]
# Epoch[3/25], G Loss: -0.4892, D Loss: -0.0533
#  12%|█▏        | 3/25 [00:08<01:02,  2.83s/it]
# Epoch[4/25], G Loss: -0.4890, D Loss: -0.0512
#  16%|█▌        | 4/25 [00:11<01:00,  2.89s/it]
# Epoch[5/25], G Loss: -0.4940, D Loss: -0.0483
#  20%|██        | 5/25 [00:14<00:58,  2.92s/it]
# Epoch[6/25], G Loss: -0.4941, D Loss: -0.0445
#  24%|██▍       | 6/25 [00:17<00:54,  2.89s/it]
# Epoch[7/25], G Loss: -0.4958, D Loss: -0.0433
#  28%|██▊       | 7/25 [00:20<00:52,  2.92s/it]
# Epoch[8/25], G Loss: -0.4916, D Loss: -0.0431
#  32%|███▏      | 8/25 [00:23<00:49,  2.91s/it]
# Epoch[9/25], G Loss: -0.4895, D Loss: -0.0441
#  36%|███▌      | 9/25 [00:26<00:47,  2.95s/it]
# Epoch[10/25], G Loss: -0.4863, D Loss: -0.0452
#  40%|████      | 10/25 [00:29<00:44,  2.95s/it]
# Epoch[11/25], G Loss: -0.4857, D Loss: -0.0470
#  44%|████▍     | 11/25 [00:32<00:41,  2.97s/it]
# Epoch[12/25], G Loss: -0.4880, D Loss: -0.0448
#  48%|████▊     | 12/25 [00:35<00:38,  2.98s/it]
# Epoch[13/25], G Loss: -0.4862, D Loss: -0.0448
#  52%|█████▏    | 13/25 [00:38<00:35,  2.99s/it]
# Epoch[14/25], G Loss: -0.4832, D Loss: -0.0480
#  56%|█████▌    | 14/25 [00:41<00:32,  2.97s/it]
# Epoch[15/25], G Loss: -0.4822, D Loss: -0.0464
#  60%|██████    | 15/25 [00:44<00:29,  2.97s/it]
# Epoch[16/25], G Loss: -0.4867, D Loss: -0.0445
#  64%|██████▍   | 16/25 [00:47<00:26,  2.99s/it]
# Epoch[17/25], G Loss: -0.4871, D Loss: -0.0452
#  68%|██████▊   | 17/25 [00:50<00:24,  3.02s/it]
# Epoch[18/25], G Loss: -0.4895, D Loss: -0.0443
#  72%|███████▏  | 18/25 [00:53<00:21,  3.01s/it]
# Epoch[19/25], G Loss: -0.4930, D Loss: -0.0414
#  76%|███████▌  | 19/25 [00:56<00:17,  2.96s/it]
# Epoch[20/25], G Loss: -0.4919, D Loss: -0.0418
#  80%|████████  | 20/25 [00:58<00:14,  2.93s/it]
# Epoch[21/25], G Loss: -0.4913, D Loss: -0.0420
#  84%|████████▍ | 21/25 [01:01<00:11,  2.91s/it]
# Epoch[22/25], G Loss: -0.4882, D Loss: -0.0424
#  88%|████████▊ | 22/25 [01:04<00:08,  2.92s/it]
# Epoch[23/25], G Loss: -0.4875, D Loss: -0.0429
#  92%|█████████▏| 23/25 [01:07<00:05,  2.90s/it]
# Epoch[24/25], G Loss: -0.4842, D Loss: -0.0449
#  96%|█████████▌| 24/25 [01:10<00:02,  2.91s/it]
# Epoch[25/25], G Loss: -0.4860, D Loss: -0.0452
# 100%|██████████| 25/25 [01:13<00:00,  2.94s/it]

# %%
# Show loss
trainer.viz_loss()
